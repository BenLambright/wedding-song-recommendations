# %%
from pyspark.sql import SparkSession
from pyspark.ml.clustering import KMeansModel
from pyspark.ml.feature import VectorAssembler, StandardScalerModel
from pyspark.sql import functions as F
from pyspark.ml.functions import array_to_vector

# %%
# creating spark app
spark = SparkSession.builder.appName("kmeans_inference").getOrCreate()

# %%
kmeans_model = KMeansModel.load('kmeans_model_big_data')
scalerModel = StandardScalerModel.load('scaler_model_kmeans_big_data')

# %%
input_columns =  [
    "af_danceability",
    "af_energy",
    "af_loudness",
    "af_speechiness",
    "af_acousticness",
    "af_instrumentalness",
    "af_valence",
    "af_tempo",
    "language_id"
]
# example_data = [0.723,0.777,-3.503,0.108,0.0426,3.68E-6,0.961,91.017,0.0]
# example_data = [0.666,0.83,-5.715,0.0751,0.0123,0.0,0.702,113.03,0.0]
# example_data = [0.627,0.416,-14.174,0.908,0.289,0.0,0.542,94.791,4.0]
# 0.561|    0.798|     -7.064|          0.32|          0.307|                0.0|      0.14| 140.837|        9.0
example_data = [0.561,0.798,-7.064,0.32,0.307,0.0,0.14,140.837,9.0]
example_df = spark.createDataFrame([example_data], input_columns)
example_df.show()

vector_assembler = VectorAssembler(inputCols = input_columns, 
                            outputCol = 'vectorized_features')
vector_dataframe = vector_assembler.transform(example_df) # df is our data without being vectorized
transformed_vectors = vector_dataframe.select('vectorized_features') # selecting the vectorized features so we can use them in a model
transformed_vectors.show(5)

# scale it next, using the same model as from training
input_scaled = scalerModel.transform(transformed_vectors)
input_scaled.show(1)
# Out:
# +---------------+---------+-----------+--------------+---------------+-------------------+----------+--------+-----------+
# |af_danceability|af_energy|af_loudness|af_speechiness|af_acousticness|af_instrumentalness|af_valence|af_tempo|language_id|
# +---------------+---------+-----------+--------------+---------------+-------------------+----------+--------+-----------+
# |          0.561|    0.798|     -7.064|          0.32|          0.307|                0.0|      0.14| 140.837|        9.0|
# +---------------+---------+-----------+--------------+---------------+-------------------+----------+--------+-----------+
#
# +--------------------+
# | vectorized_features|
# +--------------------+
# |[0.561,0.798,-7.0...|
# +--------------------+
#
# +--------------------+--------------------------+
# | vectorized_features|scaled_vectorized_features|
# +--------------------+--------------------------+
# |[0.561,0.798,-7.0...|      [3.64958367206017...|
# +--------------------+--------------------------+

# %%
preds = kmeans_model.transform(input_scaled)
preds.select("prediction").show(truncate=False)
# Out:
# +----------+
# |prediction|
# +----------+
# |7         |
# +----------+

# %%
# once we know what cluster it is, we can calculate the cosine similarity between this song and the others in that cluster
# start by getting the relevant cluster
cluster_number = preds.select("prediction").collect()[0][0]
print(f"Cluster number: {cluster_number}")
# get the relevant csv from that cluster number
cluster_df = spark.read.csv(f'big_data_clusters/cluster_{cluster_number}_big_data.csv', header=True, inferSchema=True)
df = cluster_df.withColumn(
    "scaled_vectorized_features",
    F.split("scaled_vectorized_features_str", ",").cast("array<double>")
)
df.show(5)
# Out:
# Cluster number: 7
# +------------------+--------------------+--------------------+-----------+------------------------------+--------------------------+
# |             title|              artist|               album|language_id|scaled_vectorized_features_str|scaled_vectorized_features|
# +------------------+--------------------+--------------------+-----------+------------------------------+--------------------------+
# |         #BabyBaby|             MONSTAR|Những Bản Hits Do...|       18.0|          4.670946660497695...|      [4.67094666049769...|
# |#BrooklynBloodPop!|                SyKo|  #BrooklynBloodPop!|        9.0|          4.495298248473408...|      [4.49529824847340...|
# |   #COMOTODOSFAZEM|                 NTS|     #COMOTODOSFAZEM|       21.0|          3.831737580826103...|      [3.83173758082610...|
# |           #DDDing|The Darkraver, Th...|             #DDDing|       25.0|          3.909803541725786...|      [3.90980354172578...|
# |          #Lávkóma|           Kis Grófo|            #Lávkóma|       12.0|          5.783386603318177...|      [5.78338660331817...|
# +------------------+--------------------+--------------------+-----------+------------------------------+--------------------------+
# only showing top 5 rows

# %%
import numpy as np

pdf = df.toPandas()
X = np.vstack(pdf.scaled_vectorized_features.values)
v = np.array(preds.select("scaled_vectorized_features").collect()[0][0])

cos = (X @ v) / (np.linalg.norm(X, axis=1) * np.linalg.norm(v))

pdf["cosine_similarity"] = cos
lang_filtered_pdf = pdf[pdf["language_id"] == 9.0]
lang_filtered_pdf.sort_values("cosine_similarity", ascending=False).head(20)
# Out:
#                                  title  \
# 2492                      Oh My Buddha
# 1052                       Elektryczny
# 370                               BDSM
# 3762             W Drodze Po Szczęście
# 948                         Dla sióstr
# 393                      Bajki robotów
# 3783                              Wyb?
# 1710                  Każdy Nowy Dzień
# 1334  Gorzka woda (prod. Auer) - Remix
# 1                   #BrooklynBloodPop!
# 2730                  Powiedz mi czemu
# 3879                   Zauroczyłem się
# 805                       Czarne bluzy
# 626                       CIEPŁO CIAŁA
# 735                       Ciepło ciała
# 3255               Szklanka przy patio
# 3503                    Tureckie Tango
# 5                            #MYפסטיגל
# 2011                          Mamy To!
# 4072                        Ściernisco
#
#                                               artist                  album  \
# 2492                                     Quebonafide               Egzotyka
# 1052                 Smolik, Brodka, Dawid Podsiadło            Elektryczny
# 370                                      Quebonafide    Dla fanów eklektyki
# 3762                                        O.S.T.R.  W drodze po szczęście
# 948           SB Maffija, Bedoes, Białas, White 2115          Hotel Maffija
# 393                                   Kartky, Przyłu     Outside Of Society
# 3783                     Parker Polhill, Abby Rhodes                   Wyb?
# 1710                                       Young Igi       Każdy Nowy Dzień
# 1334         Pezet, Paluch, KęKę, Sokół, Ten Typ Mes     Muzyka współczesna
# 1                                               SyKo     #BrooklynBloodPop!
# 2730                            KęKę, Paweł Domagała                Mr KęKę
# 3879                                  Smash!, Eratox        Zauroczyłem się
# 805                                    PlanBe, Tymek           Czarne bluzy
# 626                                         Wac Toja             TURBOBOOST
# 735                                         Wac Toja           Ciepło ciała
# 3255                                          Jeremi    Szklanka przy patio
# 3503                                   Danny Ferreri         Tureckie Tango
# 5                           Participants of Festigal              #MYפסטיגל
# 2011  Dj.Frodo, Young Multi, Malik Montana, Smolasty               Mamy To!
# 4072                                GOLEC UORKIESTRA     Golec uOrkiestra 2
#
#       language_id                     scaled_vectorized_features_str  \
# 2492          9.0  4.3586828168989635,4.519417459868718,-1.309135...
# 1052          9.0  4.196045398357958,3.9303480900995043,-1.215941...
# 370           9.0  4.339166326674043,3.375077782530164,-1.8445148...
# 3762          9.0  4.378199307123885,4.529074334782966,-1.5665931...
# 948           9.0  4.638419176789494,4.002774651956375,-1.5549785...
# 393           9.0  4.313144339707482,3.713068404528893,-2.0732125...
# 3783          9.0  5.145847922637434,3.3605924701587897,-1.271526...
# 1710          9.0  4.6839576539809755,3.7999802787571375,-1.39071...
# 1334          9.0  4.3326608299324025,4.147627775670116,-1.341213...
# 1             9.0  4.495298248473408,3.9303480900995043,-1.047529...
# 2730          9.0  5.399562295561402,3.5247593437010294,-1.574612...
# 3879          9.0  4.501803745215049,4.538731209697216,-1.4255583...
# 805           9.0  4.599386196339652,4.529074334782966,-1.6512141...
# 626           9.0  4.4627707647652075,3.7661812165572646,-1.05665...
# 735           9.0  4.456265268023568,3.76135277910014,-1.05167765...
# 3255          9.0  4.9441775236465855,3.1915971591594254,-1.75934...
# 3503          9.0  5.308485341178439,3.4281905945585356,-2.056343...
# 5             9.0  4.176528908133037,3.3992199698157872,-1.456530...
# 2011          9.0  4.911650039938385,4.384221211069226,-1.0046660...
# 4072          9.0  3.916309038467427,4.567701834439965,-0.9723109...
#
#                              scaled_vectorized_features  cosine_similarity
# 2492  [4.3586828168989635, 4.519417459868718, -1.309...           0.955679
# 1052  [4.196045398357958, 3.9303480900995043, -1.215...           0.947273
# 370   [4.339166326674043, 3.375077782530164, -1.8445...           0.946030
# 3762  [4.378199307123885, 4.529074334782966, -1.5665...           0.941764
# 948   [4.638419176789494, 4.002774651956375, -1.5549...           0.937809
# 393   [4.313144339707482, 3.713068404528893, -2.0732...           0.936723
# 3783  [5.145847922637434, 3.3605924701587897, -1.271...           0.935681
# 1710  [4.6839576539809755, 3.7999802787571375, -1.39...           0.935083
# 1334  [4.3326608299324025, 4.147627775670116, -1.341...           0.932655
# 1     [4.495298248473408, 3.9303480900995043, -1.047...           0.931597
# 2730  [5.399562295561402, 3.5247593437010294, -1.574...           0.929695
# 3879  [4.501803745215049, 4.538731209697216, -1.4255...           0.929560
# 805   [4.599386196339652, 4.529074334782966, -1.6512...           0.929325
# 626   [4.4627707647652075, 3.7661812165572646, -1.05...           0.928540
# 735   [4.456265268023568, 3.76135277910014, -1.05167...           0.927767
# 3255  [4.9441775236465855, 3.1915971591594254, -1.75...           0.927340
# 3503  [5.308485341178439, 3.4281905945585356, -2.056...           0.926448
# 5     [4.176528908133037, 3.3992199698157872, -1.456...           0.925879
# 2011  [4.911650039938385, 4.384221211069226, -1.0046...           0.925592
# 4072  [3.916309038467427, 4.567701834439965, -0.9723...           0.923793
