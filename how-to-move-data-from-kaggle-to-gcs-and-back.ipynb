# %% [markdown]
# # How to move data from Kaggle to GCS and back
# * The purpose of this notebook is to demonstrate how to move data from Kaggle into the Google Storage Client
# * We also demonstrate how to move data from the Google Storage Client into a Kaggle notebook
# * Note that this requires enabling Google Cloud Services in the Add-ons menu of the notebook editor.

# %% [markdown]
# **Step 1:** Import Python Modules

# %% [markdown]
# **Step 2:** Import Data from Kaggle
# * Note that you add the data to your kernel by pressing the "add data" button in the top right corner of the notebook editor

# %%
spotify_data = '/kaggle/input/spotify-charts-all-audio-data'
gcp_key = 'SECRET_KEY.json'

# %% [markdown]
# **Step 3:** Connect to GCS Storage Client and Define Some Helper Functions
# * https://cloud.google.com/storage/docs/

# %%
from google.cloud import storage
storage_client = storage.Client(project='assignment-4-475110')

# %%
# !gcloud auth activate-service-account --key-file=$gcp_key
# Out:
# Activated service account credentials for: [523399915975-compute@developer.gserviceaccount.com]

# %%
# Replace 'your-bucket-name' with your actual GCS bucket name
# Replace 'your-dataset-name' with the name of your Kaggle dataset
# This command copies all files in the input directory to the bucket
# !gsutil -m cp -r $spotify_data gs://your-bucket-name/kaggle_data/ gs://finalprojectmetcs777/
# Out:
# AccessDeniedException: 403 523399915975-compute@developer.gserviceaccount.com does not have storage.objects.list access to the Google Cloud Storage bucket. Permission 'storage.objects.list' denied on resource (or it may not exist).
# Copying file:///kaggle/input/spotify-charts-all-audio-data/merged_data.csv [Content-Type=text/csv]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# | [1/1 files][ 25.2 GiB/ 25.2 GiB] 100% Done  65.0 MiB/s ETA 00:00:00
# Operation completed over 1 objects/25.2 GiB.
# CommandException: 1 file/object could not be transferred.
